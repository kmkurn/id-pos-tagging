# %% [markdown]
# In this notebook, we're going to find out the statistics of our datasets for each fold.

# %%
import sys
sys.path.insert(0, '..')

from collections import defaultdict
from statistics import mean, median, stdev
import os

from utils import CorpusReader

# %%
def report_statistics(reader):
    n_sents, n_tokens = 0, []
    seen = set()
    tag_counter = defaultdict(int)

    for tagged_sent in reader.tagged_sents():
        n_sents += 1
        count = 0
        for word, tag in tagged_sent:
            count += 1
            seen.add(word.lower())
            tag_counter[tag] += 1
        n_tokens.append(count)

    print('Number of sentences:', n_sents)
    print('Number of word tokens:', sum(n_tokens))
    print('Number of word types:', len(seen))
    print(f'Mean, median, and stdev of sentence length: {mean(n_tokens):.2f}, {median(n_tokens)}, {stdev(n_tokens):.2f}')
    print('Tag counts:')
    for tag, count in sorted(tag_counter.items(), key=lambda p: p[1], reverse=True):
        print(tag, '=>', count, f'({count/sum(n_tokens):.2%})')

# %%
num_folds = 5

for fold in range(num_folds):
    print('### Fold', fold + 1)
    for name in ('train', 'dev', 'test'):
        corpus_path = os.path.join(
            '..', 'data', 'working', '2018-04-14', 'idn-tagged', f'{name}.{fold+1:02}.tsv')
        reader = CorpusReader(corpus_path)
        print('**', name, 'set')
        report_statistics(reader)
    print()
# Out:
# ### Fold 1
# ** train set
# Number of sentences: 7222
# Number of word tokens: 184345
# Number of word types: 13870
# Mean, median, and stdev of sentence length: 25.53, 25.0, 10.27
# Tag counts:
# NN => 44672 (24.23%)
# NNP => 24845 (13.48%)
# VB => 22790 (12.36%)
# Z => 18862 (10.23%)
# IN => 15371 (8.34%)
# CD => 12758 (6.92%)
# SC => 9366 (5.08%)
# JJ => 6997 (3.80%)
# PRP => 5408 (2.93%)
# CC => 5322 (2.89%)
# PR => 3896 (2.11%)
# MD => 3774 (2.05%)
# RB => 3463 (1.88%)
# FW => 1666 (0.90%)
# SYM => 1569 (0.85%)
# NEG => 1113 (0.60%)
# NND => 1021 (0.55%)
# OD => 541 (0.29%)
# X => 294 (0.16%)
# DT => 277 (0.15%)
# WH => 180 (0.10%)
# RP => 137 (0.07%)
# UH => 23 (0.01%)
# ** dev set
# Number of sentences: 802
# Number of word tokens: 20659
# Number of word types: 4408
# Mean, median, and stdev of sentence length: 25.76, 25.0, 10.65
# Tag counts:
# NN => 4944 (23.93%)
# NNP => 2841 (13.75%)
# VB => 2555 (12.37%)
# Z => 2159 (10.45%)
# IN => 1727 (8.36%)
# CD => 1421 (6.88%)
# SC => 1011 (4.89%)
# JJ => 761 (3.68%)
# PRP => 635 (3.07%)
# CC => 574 (2.78%)
# PR => 411 (1.99%)
# RB => 411 (1.99%)
# MD => 402 (1.95%)
# FW => 246 (1.19%)
# SYM => 201 (0.97%)
# NND => 110 (0.53%)
# NEG => 94 (0.46%)
# OD => 59 (0.29%)
# X => 33 (0.16%)
# DT => 29 (0.14%)
# WH => 24 (0.12%)
# RP => 9 (0.04%)
# UH => 2 (0.01%)
# ** test set
# Number of sentences: 2006
# Number of word tokens: 51618
# Number of word types: 7378
# Mean, median, and stdev of sentence length: 25.73, 25.0, 10.22
# Tag counts:
# NN => 12324 (23.88%)
# NNP => 6963 (13.49%)
# VB => 6388 (12.38%)
# Z => 5326 (10.32%)
# IN => 4213 (8.16%)
# CD => 3640 (7.05%)
# SC => 2703 (5.24%)
# JJ => 1966 (3.81%)
# CC => 1542 (2.99%)
# PRP => 1540 (2.98%)
# MD => 1072 (2.08%)
# PR => 1041 (2.02%)
# RB => 1029 (1.99%)
# FW => 454 (0.88%)
# SYM => 440 (0.85%)
# NEG => 313 (0.61%)
# NND => 283 (0.55%)
# OD => 138 (0.27%)
# DT => 75 (0.15%)
# X => 70 (0.14%)
# WH => 56 (0.11%)
# RP => 37 (0.07%)
# UH => 5 (0.01%)
#
# ### Fold 2
# ** train set
# Number of sentences: 7222
# Number of word tokens: 184786
# Number of word types: 13955
# Mean, median, and stdev of sentence length: 25.59, 25.0, 10.31
# Tag counts:
# NN => 44769 (24.23%)
# NNP => 24884 (13.47%)
# VB => 22796 (12.34%)
# Z => 18940 (10.25%)
# IN => 15290 (8.27%)
# CD => 12904 (6.98%)
# SC => 9467 (5.12%)
# JJ => 7049 (3.81%)
# PRP => 5355 (2.90%)
# CC => 5336 (2.89%)
# PR => 3878 (2.10%)
# MD => 3783 (2.05%)
# RB => 3517 (1.90%)
# FW => 1697 (0.92%)
# SYM => 1570 (0.85%)
# NEG => 1126 (0.61%)
# NND => 998 (0.54%)
# OD => 550 (0.30%)
# X => 282 (0.15%)
# DT => 263 (0.14%)
# WH => 180 (0.10%)
# RP => 131 (0.07%)
# UH => 21 (0.01%)
# ** dev set
# Number of sentences: 802
# Number of word tokens: 20603
# Number of word types: 4333
# Mean, median, and stdev of sentence length: 25.69, 25.0, 10.25
# Tag counts:
# NN => 4926 (23.91%)
# NNP => 2709 (13.15%)
# VB => 2548 (12.37%)
# Z => 2098 (10.18%)
# IN => 1712 (8.31%)
# CD => 1429 (6.94%)
# SC => 1041 (5.05%)
# JJ => 790 (3.83%)
# PRP => 663 (3.22%)
# CC => 588 (2.85%)
# RB => 427 (2.07%)
# PR => 415 (2.01%)
# MD => 413 (2.00%)
# FW => 242 (1.17%)
# SYM => 212 (1.03%)
# NND => 115 (0.56%)
# NEG => 112 (0.54%)
# OD => 60 (0.29%)
# DT => 34 (0.17%)
# X => 31 (0.15%)
# WH => 30 (0.15%)
# RP => 8 (0.04%)
# ** test set
# Number of sentences: 2006
# Number of word tokens: 51233
# Number of word types: 7265
# Mean, median, and stdev of sentence length: 25.54, 25.0, 10.25
# Tag counts:
# NN => 12245 (23.90%)
# NNP => 7056 (13.77%)
# VB => 6389 (12.47%)
# Z => 5309 (10.36%)
# IN => 4309 (8.41%)
# CD => 3486 (6.80%)
# SC => 2572 (5.02%)
# JJ => 1885 (3.68%)
# PRP => 1565 (3.05%)
# CC => 1514 (2.96%)
# PR => 1055 (2.06%)
# MD => 1052 (2.05%)
# RB => 959 (1.87%)
# SYM => 428 (0.84%)
# FW => 427 (0.83%)
# NND => 301 (0.59%)
# NEG => 282 (0.55%)
# OD => 128 (0.25%)
# DT => 84 (0.16%)
# X => 84 (0.16%)
# WH => 50 (0.10%)
# RP => 44 (0.09%)
# UH => 9 (0.02%)
#
# ### Fold 3
# ** train set
# Number of sentences: 7222
# Number of word tokens: 184993
# Number of word types: 13969
# Mean, median, and stdev of sentence length: 25.62, 25.0, 10.26
# Tag counts:
# NN => 44728 (24.18%)
# NNP => 24885 (13.45%)
# VB => 22846 (12.35%)
# Z => 18958 (10.25%)
# IN => 15403 (8.33%)
# CD => 12882 (6.96%)
# SC => 9487 (5.13%)
# JJ => 7018 (3.79%)
# PRP => 5405 (2.92%)
# CC => 5391 (2.91%)
# PR => 3842 (2.08%)
# MD => 3810 (2.06%)
# RB => 3553 (1.92%)
# FW => 1690 (0.91%)
# SYM => 1550 (0.84%)
# NEG => 1082 (0.58%)
# NND => 1019 (0.55%)
# OD => 534 (0.29%)
# X => 279 (0.15%)
# DT => 273 (0.15%)
# WH => 188 (0.10%)
# RP => 144 (0.08%)
# UH => 26 (0.01%)
# ** dev set
# Number of sentences: 802
# Number of word tokens: 20341
# Number of word types: 4335
# Mean, median, and stdev of sentence length: 25.36, 25.0, 10.20
# Tag counts:
# NN => 4891 (24.05%)
# NNP => 2661 (13.08%)
# VB => 2544 (12.51%)
# Z => 2078 (10.22%)
# IN => 1677 (8.24%)
# CD => 1459 (7.17%)
# SC => 1013 (4.98%)
# JJ => 741 (3.64%)
# PRP => 634 (3.12%)
# CC => 601 (2.95%)
# MD => 408 (2.01%)
# PR => 404 (1.99%)
# RB => 402 (1.98%)
# FW => 249 (1.22%)
# SYM => 203 (1.00%)
# NEG => 109 (0.54%)
# NND => 108 (0.53%)
# OD => 54 (0.27%)
# X => 36 (0.18%)
# DT => 33 (0.16%)
# WH => 23 (0.11%)
# RP => 11 (0.05%)
# UH => 2 (0.01%)
# ** test set
# Number of sentences: 2006
# Number of word tokens: 51288
# Number of word types: 7292
# Mean, median, and stdev of sentence length: 25.57, 24.0, 10.44
# Tag counts:
# NN => 12321 (24.02%)
# NNP => 7103 (13.85%)
# VB => 6343 (12.37%)
# Z => 5311 (10.36%)
# IN => 4231 (8.25%)
# CD => 3478 (6.78%)
# SC => 2580 (5.03%)
# JJ => 1965 (3.83%)
# PRP => 1544 (3.01%)
# CC => 1446 (2.82%)
# PR => 1102 (2.15%)
# MD => 1030 (2.01%)
# RB => 948 (1.85%)
# SYM => 457 (0.89%)
# FW => 427 (0.83%)
# NEG => 329 (0.64%)
# NND => 287 (0.56%)
# OD => 150 (0.29%)
# X => 82 (0.16%)
# DT => 75 (0.15%)
# WH => 49 (0.10%)
# RP => 28 (0.05%)
# UH => 2 (0.00%)
#
# ### Fold 4
# ** train set
# Number of sentences: 7222
# Number of word tokens: 184627
# Number of word types: 14053
# Mean, median, and stdev of sentence length: 25.56, 25.0, 10.28
# Tag counts:
# NN => 44472 (24.09%)
# NNP => 25007 (13.54%)
# VB => 22760 (12.33%)
# Z => 19042 (10.31%)
# IN => 15290 (8.28%)
# CD => 12862 (6.97%)
# SC => 9421 (5.10%)
# JJ => 7025 (3.80%)
# PRP => 5449 (2.95%)
# CC => 5397 (2.92%)
# PR => 3880 (2.10%)
# MD => 3798 (2.06%)
# RB => 3502 (1.90%)
# FW => 1605 (0.87%)
# SYM => 1564 (0.85%)
# NEG => 1101 (0.60%)
# NND => 1033 (0.56%)
# OD => 519 (0.28%)
# X => 290 (0.16%)
# DT => 278 (0.15%)
# WH => 180 (0.10%)
# RP => 131 (0.07%)
# UH => 21 (0.01%)
# ** dev set
# Number of sentences: 802
# Number of word tokens: 20562
# Number of word types: 4357
# Mean, median, and stdev of sentence length: 25.64, 25.0, 10.52
# Tag counts:
# NN => 4959 (24.12%)
# NNP => 2809 (13.66%)
# VB => 2571 (12.50%)
# Z => 2127 (10.34%)
# IN => 1699 (8.26%)
# CD => 1372 (6.67%)
# SC => 1021 (4.97%)
# JJ => 762 (3.71%)
# PRP => 649 (3.16%)
# CC => 594 (2.89%)
# RB => 432 (2.10%)
# MD => 399 (1.94%)
# PR => 389 (1.89%)
# SYM => 204 (0.99%)
# FW => 203 (0.99%)
# NEG => 113 (0.55%)
# NND => 101 (0.49%)
# OD => 56 (0.27%)
# DT => 35 (0.17%)
# X => 30 (0.15%)
# WH => 25 (0.12%)
# RP => 10 (0.05%)
# UH => 2 (0.01%)
# ** test set
# Number of sentences: 2006
# Number of word tokens: 51433
# Number of word types: 7230
# Mean, median, and stdev of sentence length: 25.64, 25.0, 10.24
# Tag counts:
# NN => 12509 (24.32%)
# NNP => 6833 (13.29%)
# VB => 6402 (12.45%)
# Z => 5178 (10.07%)
# IN => 4322 (8.40%)
# CD => 3585 (6.97%)
# SC => 2638 (5.13%)
# JJ => 1937 (3.77%)
# PRP => 1485 (2.89%)
# CC => 1447 (2.81%)
# PR => 1079 (2.10%)
# MD => 1051 (2.04%)
# RB => 969 (1.88%)
# FW => 558 (1.08%)
# SYM => 442 (0.86%)
# NEG => 306 (0.59%)
# NND => 280 (0.54%)
# OD => 163 (0.32%)
# X => 77 (0.15%)
# DT => 68 (0.13%)
# WH => 55 (0.11%)
# RP => 42 (0.08%)
# UH => 7 (0.01%)
#
# ### Fold 5
# ** train set
# Number of sentences: 7222
# Number of word tokens: 184683
# Number of word types: 14010
# Mean, median, and stdev of sentence length: 25.57, 25.0, 10.25
# Tag counts:
# NN => 44369 (24.02%)
# NNP => 25175 (13.63%)
# VB => 22950 (12.43%)
# Z => 18960 (10.27%)
# IN => 15342 (8.31%)
# CD => 12730 (6.89%)
# SC => 9455 (5.12%)
# JJ => 6981 (3.78%)
# PRP => 5471 (2.96%)
# CC => 5346 (2.89%)
# PR => 3880 (2.10%)
# MD => 3799 (2.06%)
# RB => 3477 (1.88%)
# FW => 1614 (0.87%)
# SYM => 1551 (0.84%)
# NEG => 1118 (0.61%)
# NND => 1047 (0.57%)
# OD => 524 (0.28%)
# X => 279 (0.15%)
# DT => 269 (0.15%)
# WH => 184 (0.10%)
# RP => 141 (0.08%)
# UH => 21 (0.01%)
# ** dev set
# Number of sentences: 802
# Number of word tokens: 20889
# Number of word types: 4401
# Mean, median, and stdev of sentence length: 26.05, 25.0, 10.58
# Tag counts:
# NN => 5030 (24.08%)
# NNP => 2780 (13.31%)
# VB => 2572 (12.31%)
# Z => 2164 (10.36%)
# IN => 1733 (8.30%)
# CD => 1459 (6.98%)
# SC => 1038 (4.97%)
# JJ => 772 (3.70%)
# PRP => 663 (3.17%)
# CC => 603 (2.89%)
# RB => 428 (2.05%)
# MD => 406 (1.94%)
# PR => 397 (1.90%)
# FW => 252 (1.21%)
# SYM => 216 (1.03%)
# NEG => 112 (0.54%)
# NND => 104 (0.50%)
# OD => 55 (0.26%)
# X => 34 (0.16%)
# DT => 33 (0.16%)
# WH => 26 (0.12%)
# RP => 10 (0.05%)
# UH => 2 (0.01%)
# ** test set
# Number of sentences: 2006
# Number of word tokens: 51050
# Number of word types: 7209
# Mean, median, and stdev of sentence length: 25.45, 25.0, 10.33
# Tag counts:
# NN => 12541 (24.57%)
# NNP => 6694 (13.11%)
# VB => 6211 (12.17%)
# Z => 5223 (10.23%)
# IN => 4236 (8.30%)
# CD => 3630 (7.11%)
# SC => 2587 (5.07%)
# JJ => 1971 (3.86%)
# CC => 1489 (2.92%)
# PRP => 1449 (2.84%)
# PR => 1071 (2.10%)
# MD => 1043 (2.04%)
# RB => 998 (1.95%)
# FW => 500 (0.98%)
# SYM => 443 (0.87%)
# NEG => 290 (0.57%)
# NND => 263 (0.52%)
# OD => 159 (0.31%)
# X => 84 (0.16%)
# DT => 79 (0.15%)
# WH => 50 (0.10%)
# RP => 32 (0.06%)
# UH => 7 (0.01%)
